# %% [markdown]
# ## **16. 특징 선택**

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# 타임스탬프 파싱 함수

def parser(x):
    return datetime.strptime(x, '%Y-%m-%d %H:%M:%S')

# %%
# 데이터셋 로딩

from datetime import datetime
import os
import pandas as pd

# 데이터셋 로딩
def parser(x):
    return datetime.strptime(x, '%Y-%m-%d %H:%M:%S')

filename = r'C:\Users\eunjin\data\AirQualityUCI_refined.csv'

# os 모듈을 import 했기 때문에 이제 정상 작동합니다!
if os.path.exists(filename):
    df = pd.read_csv(filename,
                     index_col=[0],
                     parse_dates=[0],
                     date_format='%Y-%m-%d %H:%M:%S') 
    
    display(df.head()) # 데이터 앞부분 확인
else:
    print(f"죄송합니다. 지정하신 경로에 파일이 존재하지 않습니다:\n{filename}")
# Out:
#                      CO(GT)  PT08.S1(CO)  PT08.S2(NMHC)  NOx(GT)  \
# Datetime
# 2004-03-10 18:00:00     2.6       1360.0         1046.0    166.0
# 2004-03-10 19:00:00     2.0       1292.0          955.0    103.0
# 2004-03-10 20:00:00     2.2       1402.0          939.0    131.0
# 2004-03-10 21:00:00     2.2       1376.0          948.0    172.0
# 2004-03-10 22:00:00     1.6       1272.0          836.0    131.0
#
#                      PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)    RH  \
# Datetime
# 2004-03-10 18:00:00        1056.0    113.0        1692.0       1268.0  48.9
# 2004-03-10 19:00:00        1174.0     92.0        1559.0        972.0  47.7
# 2004-03-10 20:00:00        1140.0    114.0        1555.0       1074.0  54.0
# 2004-03-10 21:00:00        1092.0    122.0        1584.0       1203.0  60.0
# 2004-03-10 22:00:00        1205.0    116.0        1490.0       1110.0  59.6
#
#                          AH  C6H6(GT)
# Datetime
# 2004-03-10 18:00:00  0.7578      11.9
# 2004-03-10 19:00:00  0.7255       9.4
# 2004-03-10 20:00:00  0.7502       9.0
# 2004-03-10 21:00:00  0.7867       9.2
# 2004-03-10 22:00:00  0.7888       6.5

# %%
# 시각화 설정 옵션 (qt5 설치된 환경에서만 실행)
#%matplotlib qt5
#%config InlineBackend.figure_format = 'svg'

#plt.rcParams['figure.figsize'] = [12, 5]
#plt.rcParams['font.size'] = 13
#plt.ion()

# %%
# [+] 전체 변수에 대한 결측치 처리 (선형 보간)
df = df.interpolate(method='linear')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9357 entries, 2004-03-10 18:00:00 to 2005-04-04 14:00:00
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CO(GT)         9357 non-null   float64
#  1   PT08.S1(CO)    9357 non-null   float64
#  2   PT08.S2(NMHC)  9357 non-null   float64
#  3   NOx(GT)        9357 non-null   float64
#  4   PT08.S3(NOx)   9357 non-null   float64
#  5   NO2(GT)        9357 non-null   float64
#  6   PT08.S4(NO2)   9357 non-null   float64
#  7   PT08.S5(O3)    9357 non-null   float64
#  8   RH             9357 non-null   float64
#  9   AH             9357 non-null   float64
#  10  C6H6(GT)       9357 non-null   float64
# dtypes: float64(11)
# memory usage: 877.2 KB

# %%
# 상관행렬 시각화
sns.pairplot(
    df, 
    kind='reg', 
    diag_kind='kde', 
    plot_kws={'scatter_kws': {'alpha': 0.1}}
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 # 상관행렬 시각화
# ----> 2 sns.pairplot(
#       3     df,
#       4     kind='reg',
#       5     diag_kind='kde',
#       6     plot_kws={'scatter_kws': {'alpha': 0.1}}
#       7 )
#
# NameError: name 'sns' is not defined

# %%
# [+] 상관계수 측정
# 데이터프레임 내 수치형 변수들 간의 피어슨 상관계수를 계산합니다.
corr_matrix = df.corr(numeric_only=True)

# 계산된 상관계수 행렬을 출력합니다.
display(corr_matrix)
# Out:
#                  CO(GT)  PT08.S1(CO)  PT08.S2(NMHC)   NOx(GT)  PT08.S3(NOx)  \
# CO(GT)         1.000000     0.793021       0.807142  0.789544     -0.647024
# PT08.S1(CO)    0.793021     1.000000       0.892045  0.667099     -0.777083
# PT08.S2(NMHC)  0.807142     0.892045       1.000000  0.646925     -0.793180
# NOx(GT)        0.789544     0.667099       0.646925  1.000000     -0.626814
# PT08.S3(NOx)  -0.647024    -0.777083      -0.793180 -0.626814      1.000000
# NO2(GT)        0.673540     0.617714       0.601650  0.763038     -0.622142
# PT08.S4(NO2)   0.558919     0.667361       0.765290  0.214655     -0.528604
# PT08.S5(O3)    0.773442     0.901731       0.875130  0.735982     -0.798375
# RH             0.061133     0.115498      -0.089798  0.212168     -0.062422
# AH             0.063548     0.112241       0.170344 -0.122630     -0.212475
# C6H6(GT)       0.761713     0.813633       0.911915  0.587481     -0.685988
#
#                 NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)        RH        AH  \
# CO(GT)         0.673540      0.558919     0.773442  0.061133  0.063548
# PT08.S1(CO)    0.617714      0.667361     0.901731  0.115498  0.112241
# PT08.S2(NMHC)  0.601650      0.765290     0.875130 -0.089798  0.170344
# NOx(GT)        0.763038      0.214655     0.735982  0.212168 -0.122630
# PT08.S3(NOx)  -0.622142     -0.528604    -0.798375 -0.062422 -0.212475
# NO2(GT)        1.000000      0.134203     0.679754 -0.077801 -0.322243
# PT08.S4(NO2)   0.134203      1.000000     0.569545 -0.026601  0.629481
# PT08.S5(O3)    0.679754      0.569545     1.000000  0.127247  0.044611
# RH            -0.077801     -0.026601     0.127247  1.000000  0.170529
# AH            -0.322243      0.629481     0.044611  0.170529  1.000000
# C6H6(GT)       0.514042      0.742489     0.777093 -0.055630  0.178522
#
#                C6H6(GT)
# CO(GT)         0.761713
# PT08.S1(CO)    0.813633
# PT08.S2(NMHC)  0.911915
# NOx(GT)        0.587481
# PT08.S3(NOx)  -0.685988
# NO2(GT)        0.514042
# PT08.S4(NO2)   0.742489
# PT08.S5(O3)    0.777093
# RH            -0.055630
# AH             0.178522
# C6H6(GT)       1.000000

# %% [markdown]
# **모델 학습 및 특징 중요도 출력**
#
# 특징 집합을 훈련 데이터로 학습하여 일산화탄소를 예측하는 회귀 모델
# - 레이블: 일산화탄소(`CO(GT)`)
# - 특징 집합: `CO(GT)`를 제외한 나머지 변수

# %%
print("현재 데이터 행 개수:", len(df))
# Out:
# 현재 데이터 행 개수: 9357

# %%
# [+] 학습 데이터셋 준비
X = df.iloc[:, 1:] # 훈련 데이터
y = df.iloc[:, 0]  # 레이블 데이터
print(X.shape, y.shape)
# Out:
# (9357, 10) (9357,)

# %%
from sklearn.model_selection import train_test_split

# [+] 훈련 / 테스트 분할
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size = 0.2,
    random_state=1
)

# %%
from sklearn.ensemble import RandomForestRegressor  # 랜덤 포레스트 회귀 모형

model = RandomForestRegressor()# [+] 모델 객체 생성
model.fit(X_train, y_train) # [+] 모델 학습
# Out:
# RandomForestRegressor()

# %%
# [+] 예측 수행
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error

# [+] MAE 계산
mae = mean_absolute_error(y_test, y_pred)
print(f"MAE (Mean Absolute Error): {mae:.4f}")
# Out:
# MAE (Mean Absolute Error): 0.2947

# %%
# [+] 특징 중요도 출력
model.feature_importances_
# Out:
# array([0.05735679, 0.53565675, 0.20565042, 0.01852775, 0.03924792,
#        0.01878078, 0.01677947, 0.01397216, 0.02406333, 0.06996462])

# %%
# 특징 중요도 계산
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances
# Out:
# PT08.S1(CO)      0.057357
# PT08.S2(NMHC)    0.535657
# NOx(GT)          0.205650
# PT08.S3(NOx)     0.018528
# NO2(GT)          0.039248
# PT08.S4(NO2)     0.018781
# PT08.S5(O3)      0.016779
# RH               0.013972
# AH               0.024063
# C6H6(GT)         0.069965
# dtype: float64

# %%
import matplotlib.pyplot as plt

# 특징 중요도 시각화
feat_importances.sort_values(ascending=True).plot(kind='barh')

plt.show()
